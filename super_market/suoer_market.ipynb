# %%
import pandas as pd
import plotly.express as px
import seaborn as sns

# %%
df = pd.read_excel('supermarkt_sales.xlsx', sheet_name='Sales' ,skiprows=3 , usecols='B:R',nrows=1000,)

# %%
df.head()
# Out:
#     Invoice ID Branch       City Customer_type  Gender  \
# 0  750-67-8428      A     Mumbai        Member  Female
# 1  226-31-3081      C      Delhi        Normal  Female
# 2  631-41-3108      A  Bangalore        Normal    Male
# 3  123-19-1176      A  Hyderabad        Member    Male
# 4  373-73-7910      A  Ahmedabad        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total  Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715  2021
# 1  Electronic accessories       15.28         5   3.8200   80.2200  2021
# 2      Home and lifestyle       46.33         7  16.2155  340.5255  2021
# 3       Health and beauty       58.22         8  23.2880  489.0480  2021
# 4       Sports and travel       86.31         7  30.2085  634.3785  2021
#
#        Time      Payment    cogs  gross margin percentage  gross income  \
# 0  13:08:00      Ewallet  522.83                 4.761905       26.1415
# 1  10:29:00         Cash   76.40                 4.761905        3.8200
# 2  13:23:00  Credit card  324.31                 4.761905       16.2155
# 3  20:33:00      Ewallet  465.76                 4.761905       23.2880
# 4  10:37:00      Ewallet  604.17                 4.761905       30.2085
#
#    Rating
# 0     9.1
# 1     9.6
# 2     7.4
# 3     8.4
# 4     5.3

# %%
sales_by_product_line = df.groupby(["Product line"])[["Total"]].sum()
fig_product_sales = px.bar(
    sales_by_product_line,
    x="Total",
    y=sales_by_product_line.index,
    orientation="h",
    title="<b>Sales by Product Line</b>",
    color_discrete_sequence=["#0083B8"] * len(sales_by_product_line),
    template="plotly_white",
)
